# %%
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

import sys
sys.path.append('../SWMat/')
from SWMat import SWMat

# %%
swm = SWMat(plt)
xs = np.array([[1, 2, 3, 4], [1, 2, 3, 4]]).T
ys =  np.array([[1, 4, 2, 6], [4, 2, 6, 5]]).T
ls = swm.line_plot(xs, ys, line_labels=["Aaasdasf", "Basfasf"], highlight=0, lw=3, label_points_after=(2.5, [True, False]), xlabel="x ->")
swm.text("Title", position="title", fontsize=30);
